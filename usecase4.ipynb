# %%
import pandas as pd

# %%
data=pd.read_excel('DataOut.xlsx')

# %%
#data['Loss_ALAE_Ratio']=data['Loss_ALAE_Ratio'].strip("%")
Loss_ALAE_value=[]
for loss in data['Loss_ALAE_Ratio']:
    Loss_ALAE_value.append(float(loss.strip('%'))/100)

# %%
data['Loss_ALAE_value']=Loss_ALAE_value

# %%
data.head()
# Out:
#    Acc_Hldr_Fein Loss_ALAE_Ratio distance_to_significant_wf_risk_params  \
# 0      900174266         458.14%                                3560 ft
# 1      651307969         168.72%                                6581 ft
# 2      205994162         166.52%                                6925 ft
# 3      203032924         165.14%                                    NaN
# 4      752580200         152.87%                                2962 ft
#
#    drive_distance_fire_station hail hazardhub_flood hurricane  \
# 0                         1.59    D               B         F
# 1                         0.75    D               F         F
# 2                         0.57    D               B         D
# 3                         6.19    D               A       NaN
# 4                         1.66    D               A       NaN
#
#                                              hydrant  nearest_fire_station  \
# 0  > 500 feet AND <= 1,000 feet from Reported Hyd...                   4.0
# ...

# %%
data.corr()
# Out:
#                                         Acc_Hldr_Fein  \
# Acc_Hldr_Fein                                1.000000
# drive_distance_fire_station                 -0.154253
# nearest_fire_station                        -0.146180
# number_of_fire_stations_within_5_miles      -0.059417
# Loss_ALAE_value                              0.126245
#
#                                         drive_distance_fire_station  \
# Acc_Hldr_Fein                                             -0.154253
# drive_distance_fire_station                                1.000000
# nearest_fire_station                                       0.848064
# number_of_fire_stations_within_5_miles                    -0.411176
# Loss_ALAE_value                                            0.040398
#
#                                         nearest_fire_station  \
# Acc_Hldr_Fein                                      -0.146180
# drive_distance_fire_station                         0.848064
# ...
